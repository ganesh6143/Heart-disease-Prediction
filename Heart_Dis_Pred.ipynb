# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import data

# %%
df = pd.read_csv(r'labels.csv')
df
# Out:
#     patient_id  heart_disease_present
# 0       0z64un                      0
# 1       ryoo3j                      0
# 2       yt1s1x                      1
# 3       l2xjde                      1
# 4       oyt4ek                      0
# ..         ...                    ...
# 175     5qfar3                      1
# 176     2s2b1f                      1
# 177     nsd00i                      1
# 178     0xw93k                      0
# 179     2nx10r                      0
#
# [180 rows x 2 columns]

# %%
df1 = pd.read_csv(r'values.csv')
df1
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %%
df2 = pd.merge(df1, df, on='patient_id', how='inner')
df2
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %% [markdown]
# # Basic Checks

# %%
df2.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
df2.tail()
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 175                     125                4                  2
# 176                     180                4                  0
# 177                     125                3                  0
# 178                     124                3                  2
# 179                     160                3                  1
#
#      fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 175                                     1                    0
# ...

# %%
df2.shape
# Out:
# (180, 15)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   patient_id                            180 non-null    object
#  1   slope_of_peak_exercise_st_segment     180 non-null    int64
#  2   thal                                  180 non-null    object
#  3   resting_blood_pressure                180 non-null    int64
#  4   chest_pain_type                       180 non-null    int64
#  5   num_major_vessels                     180 non-null    int64
#  6   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  7   resting_ekg_results                   180 non-null    int64
#  8   serum_cholesterol_mg_per_dl           180 non-null    int64
#  9   oldpeak_eq_st_depression              180 non-null    float64
#  10  sex                                   180 non-null    int64
# ...

# %%
df2.isnull().sum()
# Out:
# patient_id                              0
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# resting_blood_pressure                  0
# chest_pain_type                         0
# num_major_vessels                       0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# oldpeak_eq_st_depression                0
# sex                                     0
# age                                     0
# max_heart_rate_achieved                 0
# exercise_induced_angina                 0
# heart_disease_present                   0
# dtype: int64

# %%
df2.isnull()
# Out:
#      patient_id  slope_of_peak_exercise_st_segment   thal  \
# 0         False                              False  False
# 1         False                              False  False
# 2         False                              False  False
# 3         False                              False  False
# 4         False                              False  False
# ..          ...                                ...    ...
# 175       False                              False  False
# 176       False                              False  False
# 177       False                              False  False
# 178       False                              False  False
# 179       False                              False  False
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     False            False              False
# 1                     False            False              False
# 2                     False            False              False
# ...

# %%
df2.columns
# Out:
# Index(['patient_id', 'slope_of_peak_exercise_st_segment', 'thal',
#        'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels',
#        'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
#        'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
#        'max_heart_rate_achieved', 'exercise_induced_angina',
#        'heart_disease_present'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
df2
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %%
column_types = df2.dtypes

numerical_columns = column_types[column_types != 'object'].index.tolist()
categorical_columns = column_types[column_types == 'object'].index.tolist()

print("Numerical columns:", numerical_columns)
print("Categorical columns:", categorical_columns)
# Out:
# Numerical columns: ['slope_of_peak_exercise_st_segment', 'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels', 'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results', 'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age', 'max_heart_rate_achieved', 'exercise_induced_angina', 'heart_disease_present']
# Categorical columns: ['patient_id', 'thal']

# %%
plt.figure(figsize=(20, 22))
plotnumber = 1

for col in numerical_columns: 
    plt.subplot(7, 3, plotnumber)
    sns.histplot(df2[col], kde=True) 
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
sns.countplot(x=df2.thal);

# %% [markdown]
# # Bivarient Ananysis

# %%
df2.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
plotnumber = 1
plt.figure(figsize=(20,10))
for i in df2:
    plt.subplot(10,2,plotnumber)
    sns.stripplot(x=df2[i],y=df2.heart_disease_present)
    plotnumber = plotnumber + 1
plt.tight_layout()
plt.show()

# %%
sns.barplot(x=df2.thal, y=df2.heart_disease_present);

# %% [markdown]
# # Data Preprocessing

# %%
df2.isnull().sum()
# Out:
# patient_id                              0
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# resting_blood_pressure                  0
# chest_pain_type                         0
# num_major_vessels                       0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# oldpeak_eq_st_depression                0
# sex                                     0
# age                                     0
# max_heart_rate_achieved                 0
# exercise_induced_angina                 0
# heart_disease_present                   0
# dtype: int64

# %% [markdown]
# # Encodeing

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   patient_id                            180 non-null    object
#  1   slope_of_peak_exercise_st_segment     180 non-null    int64
#  2   thal                                  180 non-null    object
#  3   resting_blood_pressure                180 non-null    int64
#  4   chest_pain_type                       180 non-null    int64
#  5   num_major_vessels                     180 non-null    int64
#  6   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  7   resting_ekg_results                   180 non-null    int64
#  8   serum_cholesterol_mg_per_dl           180 non-null    int64
#  9   oldpeak_eq_st_depression              180 non-null    float64
#  10  sex                                   180 non-null    int64
# ...

# %%
df2.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
df2.thal = lb.fit_transform(df2.thal)

# %%
df2
# Out:
#     patient_id  slope_of_peak_exercise_st_segment  thal  \
# 0       0z64un                                  1     1
# 1       ryoo3j                                  2     1
# 2       yt1s1x                                  1     1
# 3       l2xjde                                  1     2
# 4       oyt4ek                                  3     2
# ..         ...                                ...   ...
# 175     5qfar3                                  2     2
# 176     2s2b1f                                  2     1
# 177     nsd00i                                  2     2
# 178     0xw93k                                  1     1
# 179     2nx10r                                  1     1
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# 1                       110                3                  0
# 2                       125                4                  3
# ...

# %%
df2.drop('patient_id',axis=1)
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                    1     1                     128
# 1                                    2     1                     110
# 2                                    1     1                     125
# 3                                    1     2                     152
# 4                                    3     2                     178
# ..                                 ...   ...                     ...
# 175                                  2     2                     125
# 176                                  2     1                     180
# 177                                  2     2                     125
# 178                                  1     1                     124
# 179                                  1     1                     160
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# ...

# %%
df2 = df2.drop('patient_id',axis=1)

# %%
df2
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                    1     1                     128
# 1                                    2     1                     110
# 2                                    1     1                     125
# 3                                    1     2                     152
# 4                                    3     2                     178
# ..                                 ...   ...                     ...
# 175                                  2     2                     125
# 176                                  2     1                     180
# 177                                  2     2                     125
# 178                                  1     1                     124
# 179                                  1     1                     160
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   slope_of_peak_exercise_st_segment     180 non-null    int64
#  1   thal                                  180 non-null    int32
#  2   resting_blood_pressure                180 non-null    int64
#  3   chest_pain_type                       180 non-null    int64
#  4   num_major_vessels                     180 non-null    int64
#  5   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  6   resting_ekg_results                   180 non-null    int64
#  7   serum_cholesterol_mg_per_dl           180 non-null    int64
#  8   oldpeak_eq_st_depression              180 non-null    float64
#  9   sex                                   180 non-null    int64
#  10  age                                   180 non-null    int64
# ...

# %% [markdown]
# # Scaling

# %%
df2.head()
# Out:
#    slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                  1     1                     128
# 1                                  2     1                     110
# 2                                  1     1                     125
# 3                                  1     2                     152
# 4                                  3     2                     178
#
#    chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# 0                2                  0                                     0
# 1                3                  0                                     0
# 2                4                  3                                     0
# 3                4                  0                                     0
# 4                1                  0                                     0
#
#    resting_ekg_results  serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

# %%
ms.fit_transform(df2[['resting_blood_pressure']])
# Out:
# array([[0.39534884],
#        [0.18604651],
#        [0.36046512],
#        [0.6744186 ],
#        [0.97674419],
#        [0.41860465],
#        [0.65116279],
#        [0.65116279],
#        [0.88372093],
#        [0.30232558],
#        [0.30232558],
#        [0.53488372],
#        [0.53488372],
#        [0.51162791],
#        [0.30232558],
#        [0.58139535],
#        [0.41860465],
#        [0.41860465],
#        [0.41860465],
#        [0.48837209],
#        [0.76744186],
#        [0.1627907 ],
#        [0.13953488],
#        [0.76744186],
#        [0.72093023],
#        [0.30232558],
#        [0.39534884],
#        [0.39534884],
#        [0.53488372],
#        [0.18604651],
#        [0.41860465],
#        [0.65116279],
#        [0.53488372],
#        [1.        ],
#        [0.20930233],
#        [0.3255814 ],
#        [0.65116279],
#        [0.34883721],
#        [0.30232558],
#        [0.39534884],
#        [0.65116279],
#        [0.47674419],
#        [0.18604651],
# ...

# %%
df2.resting_blood_pressure = ms.fit_transform(df2[['resting_blood_pressure']])
df2.max_heart_rate_achieved = ms.fit_transform(df2[['max_heart_rate_achieved']])
df2.serum_cholesterol_mg_per_dl = ms.fit_transform(df2[['serum_cholesterol_mg_per_dl']])

# %%
df2.head()
# Out:
#    slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                  1     1                0.395349
# 1                                  2     1                0.186047
# 2                                  1     1                0.360465
# 3                                  1     2                0.674419
# 4                                  3     2                0.976744
#
#    chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# 0                2                  0                                     0
# 1                3                  0                                     0
# 2                4                  3                                     0
# 3                4                  0                                     0
# 4                1                  0                                     0
#
#    resting_ekg_results  serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  \
# ...

# %% [markdown]
# # Feature Selection`

# %%
df2.head()
# Out:
#    slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                  1     1                0.395349
# 1                                  2     1                0.186047
# 2                                  1     1                0.360465
# 3                                  1     2                0.674419
# 4                                  3     2                0.976744
#
#    chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# 0                2                  0                                     0
# 1                3                  0                                     0
# 2                4                  3                                     0
# 3                4                  0                                     0
# 4                1                  0                                     0
#
#    resting_ekg_results  serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  \
# ...

# %%
df2.corr()
# Out:
#                                       slope_of_peak_exercise_st_segment  \
# slope_of_peak_exercise_st_segment                              1.000000
# thal                                                           0.154101
# resting_blood_pressure                                         0.098287
# chest_pain_type                                                0.121207
# num_major_vessels                                              0.076832
# fasting_blood_sugar_gt_120_mg_per_dl                           0.050199
# resting_ekg_results                                            0.172191
# serum_cholesterol_mg_per_dl                                   -0.032348
# oldpeak_eq_st_depression                                       0.615948
# sex                                                            0.093340
# age                                                            0.169918
# max_heart_rate_achieved                                       -0.418102
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   slope_of_peak_exercise_st_segment     180 non-null    int64
#  1   thal                                  180 non-null    int32
#  2   resting_blood_pressure                180 non-null    float64
#  3   chest_pain_type                       180 non-null    int64
#  4   num_major_vessels                     180 non-null    int64
#  5   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  6   resting_ekg_results                   180 non-null    int64
#  7   serum_cholesterol_mg_per_dl           180 non-null    float64
#  8   oldpeak_eq_st_depression              180 non-null    float64
#  9   sex                                   180 non-null    int64
#  10  age                                   180 non-null    int64
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2.corr(),annot=True);

# %% [markdown]
# # Model Creation

# %%
df2.columns
# Out:
# Index(['slope_of_peak_exercise_st_segment', 'thal', 'resting_blood_pressure',
#        'chest_pain_type', 'num_major_vessels',
#        'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
#        'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
#        'max_heart_rate_achieved', 'exercise_induced_angina',
#        'heart_disease_present'],
#       dtype='object')

# %%
x = df2[['slope_of_peak_exercise_st_segment', 'thal', 'resting_blood_pressure',
       'chest_pain_type', 'num_major_vessels',
       'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results',
       'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
       'max_heart_rate_achieved', 'exercise_induced_angina']]

# %%
y = df2['heart_disease_present']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=42)

# %%
x_train
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 132                                  1     1                0.418605
# 90                                   2     1                0.465116
# 38                                   1     1                0.302326
# 169                                  2     1                0.186047
# 115                                  1     1                0.534884
# ..                                 ...   ...                     ...
# 71                                   1     1                0.209302
# 106                                  1     2                0.651163
# 14                                   2     2                0.302326
# 92                                   1     1                0.476744
# 102                                  2     2                0.186047
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# ...

# %%
x_test
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 19                                   1     1                0.488372
# 42                                   1     1                0.186047
# 153                                  1     1                0.209302
# 78                                   2     2                0.593023
# 145                                  1     1                0.534884
# 15                                   2     2                0.581395
# 24                                   1     1                0.720930
# 68                                   2     1                0.476744
# 113                                  2     2                1.000000
# 118                                  2     2                0.441860
# 93                                   2     2                0.534884
# 159                                  2     2                0.418605
# 69                                   2     2                0.302326
# ...

# %%
y_train
# Out:
# 132    0
# 90     0
# 38     0
# 169    0
# 115    0
#       ..
# 71     0
# 106    0
# 14     1
# 92     0
# 102    1
# Name: heart_disease_present, Length: 135, dtype: int64

# %%
y_test
# Out:
# 19     1
# 42     0
# 153    1
# 78     1
# 145    0
# 15     1
# 24     0
# 68     0
# 113    1
# 118    1
# 93     1
# 159    1
# 69     1
# 142    0
# 45     1
# 16     0
# 51     0
# 125    0
# 96     1
# 56     1
# 97     0
# 120    1
# 143    1
# 30     0
# 9      0
# 172    1
# 60     0
# 18     0
# 148    1
# 173    1
# 109    1
# 55     0
# 140    1
# 126    0
# 66     1
# 29     0
# 117    1
# 65     1
# 67     0
# 31     1
# 12     1
# 41     0
# 124    1
# 100    0
# 161    1
# Name: heart_disease_present, dtype: int64

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (135, 13)
# (135,)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
